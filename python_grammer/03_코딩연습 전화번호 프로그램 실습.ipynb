# %% [markdown]
# # 전화번호 프로그램 만들기
#
# * 홍길동 010-123-4567
# * 기능1 : 연락처 추가
# * 기능2 : 연락처 전체 보기
# * 기능3 : 검색, 이름을 입력받아서 전화번호 조회
# * 기능4 : 수정, 이름을 입력받아서 전화번호 입력수정
# * 기능5 : 삭제, 이름 입력받아서 삭제
# * 기능6 : 프로그램 종료

# %%
phone_num = {}

while True:
    print("\n--------------------")
    print("전화번호 프로그램")
    print("1번 연락처 추가")
    print("2번 연락처 전체 보기")
    print("3번 전화번호 검색")
    print("4번 전화번호 수정")
    print("5번 연락처 삭제")
    print("6번 프로그램 종료")
    print("--------------------")
    
    num = input("\n기능 번호를 입력하여 프로그램을 사용해보세요.: ")

    if num == '1':
        name = input("이름: ")
        number = input("전화번호: ")
        phone_num[name] = number
        print(f"{name}의 연락처를 추가했습니다.")
    elif num == '2':
        print("전체 연락처: ")
        for name, number in phone_num.items():
            print(f"{name} {number}")
    elif num == '3':
        name = input("전화번호를 검색할 사람의 이름: ")
        if name in phone_num:
            print(f"{name}의 전화번호는 {phone_num[name]} 입니다.")
        else:
            print(f"{name}의 연락처는 존재하지 않습니다.")
    elif num == '4':
        name = input("전화번호를 수정할 사람의 이름을 입력하세요: ")
        if name in phone_num:
            new_number = input("수정할 전화번호를 입력하세요: ")
            phone_num[name] = new_number
            print(f"{name}의 전화번호가 수정되었습니다.")
        else:
            print(f"{name}의 연락처는 존재하지 않습니다.")
    elif num == '5':
        name = input("연락처를 삭제할 사람의 이름을 입력하세요: ")
        if name in phone_num:
            del phone_num[name]
            print(f"{name}의 연락처가 삭제되었습니다.")
        else:
            print(f"{name}의 연락처는 존재하지 않습니다.")
    elif num == '6':
        print("전화번호 프로그램을 종료합니다.")
        break
    else:
        print("해당 번호의 기능은 존재하지 않습니다.")
# Out:
# --------------------
# 전화번호 프로그램
# 1번 연락처 추가
# 2번 연락처 전체 보기
# 3번 전화번호 검색
# 4번 전화번호 수정
# 5번 연락처 삭제
# 6번 프로그램 종료
# --------------------
#
# 기능 번호를 입력하여 프로그램을 사용해보세요.: 1
# 이름: 오유진
# 전화번호: 010-6228-9424
# 오유진의 연락처를 추가했습니다.
#
# --------------------
# 전화번호 프로그램
# 1번 연락처 추가
# 2번 연락처 전체 보기
# 3번 전화번호 검색
# 4번 전화번호 수정
# 5번 연락처 삭제
# 6번 프로그램 종료
# --------------------
#
# 기능 번호를 입력하여 프로그램을 사용해보세요.: 2
# 전체 연락처:
# 오유진 010-6228-9424
#
# --------------------
# 전화번호 프로그램
# 1번 연락처 추가
# 2번 연락처 전체 보기
# 3번 전화번호 검색
# 4번 전화번호 수정
# 5번 연락처 삭제
# 6번 프로그램 종료
# --------------------
#
# 기능 번호를 입력하여 프로그램을 사용해보세요.: 3
# 전화번호를 검색할 사람의 이름: 오유진
# 오유진의 전화번호는 010-6228-9424 입니다.
#
# --------------------
# 전화번호 프로그램
# 1번 연락처 추가
# 2번 연락처 전체 보기
# 3번 전화번호 검색
# 4번 전화번호 수정
# 5번 연락처 삭제
# 6번 프로그램 종료
# --------------------
#
# 기능 번호를 입력하여 프로그램을 사용해보세요.: 4
# 전화번호를 수정할 사람의 이름을 입력하세요: 오유진
# 수정할 전화번호를 입력하세요: 010-1111-2222
# 오유진의 전화번호가 수정되었습니다.
#
# --------------------
# 전화번호 프로그램
# 1번 연락처 추가
# 2번 연락처 전체 보기
# 3번 전화번호 검색
# 4번 전화번호 수정
# ...
